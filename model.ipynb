# %% [markdown]
# # Model

# %% [markdown]
# ## References
# https://www.tensorflow.org/tutorials/load_data/csv - Getting the dataset
#
# https://www.tensorflow.org/guide/keras/save_and_serialize - Saving the model
#
# https://github.com/ianmcloughlin/jupyter-teaching-notebooks/blob/master/keras-linear.ipynb - Taken for predictions graph

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Retrieving the dataset.

# %%
dataset = pd.read_csv("https://raw.githubusercontent.com/ianmcloughlin/2020A-machstat-project/master/dataset/powerproduction.csv")

# %% [markdown]
# Making sure the dataset is retrieved by displaying the first few values.

# %%
dataset.head()
# Out:
#    speed  power
# 0  0.000    0.0
# 1  0.125    0.0
# 2  0.150    0.0
# 3  0.225    0.0
# 4  0.275    0.0

# %% [markdown]
# Seperating the power and speed into arrays dataset_features handles speed and dataset_power handles the power data. I used the pop function to take out the power values

# %%
dataset_features = dataset.copy()
dataset_power = dataset_features.pop('power')
dataset_power = np.array(dataset_power)
dataset_features = np.array(dataset_features)

# %%
dataset_model = tf.keras.Sequential([
  keras.layers.Dense(64),
  keras.layers.Dense(1)
])

dataset_model.compile(loss = tf.losses.MeanSquaredError(), optimizer = tf.optimizers.Adam())
history = dataset_model.fit(dataset_features, dataset_power, epochs=500)
dataset_model.summary()
# Out:
# Epoch 1/500
# 16/16 [==============================] - 6s 7ms/step - loss: 4098.6766
# Epoch 2/500
# 16/16 [==============================] - 0s 2ms/step - loss: 3711.4707
# Epoch 3/500
# 16/16 [==============================] - 0s 2ms/step - loss: 2938.6773
# Epoch 4/500
# 16/16 [==============================] - 0s 2ms/step - loss: 2821.4749
# Epoch 5/500
# 16/16 [==============================] - 0s 2ms/step - loss: 2363.2209
# Epoch 6/500
# 16/16 [==============================] - 0s 2ms/step - loss: 1911.8174
# Epoch 7/500
# 16/16 [==============================] - 0s 2ms/step - loss: 1615.0374
# Epoch 8/500
# 16/16 [==============================] - 0s 2ms/step - loss: 1196.4471
# Epoch 9/500
# 16/16 [==============================] - 0s 2ms/step - loss: 1038.4099
# Epoch 10/500
# 16/16 [==============================] - 0s 2ms/step - loss: 877.9592
# Epoch 11/500
# 16/16 [==============================] - 0s 2ms/step - loss: 750.1032
# Epoch 12/500
# ...

# %% [markdown]
# Making a prediction based on the dataset_features which contains the speed and dataset_power which contains the power.

# %%
plt.plot(dataset_features, dataset_power, label='actual')
plt.plot(dataset_features, dataset_model.predict(dataset_power), label='prediction')
plt.legend();

# %% [markdown]
# Saving in a h5 format allows to save the model's architecture, weight values and information got from the compile function.

# %%
dataset_model.save("model.h5")
